# %% [markdown]
# <a href="https://colab.research.google.com/github/rontalapoojareddy/ADSA-Lab1/blob/main/ADSA_Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class StackLL:
    def __init__(self):
        self.head = None

    def push(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def pop(self):
        if self.head is None:
            return None
        data = self.head.data
        self.head = self.head.next
        return data

    def is_empty(self):
        return self.head is None


class QueueLL:
    def __init__(self):
        self.front = None
        self.rear = None

    def enqueue(self, data):
        new_node = Node(data)
        if self.rear is None:
            self.front = self.rear = new_node
        else:
            self.rear.next = new_node
            self.rear = new_node

    def dequeue(self):
        if self.front is None:
            return None
        data = self.front.data
        self.front = self.front.next
        if self.front is None:
            self.rear = None
        return data

    def is_empty(self):
        return self.front is None


class BrowserNavigation:
    def __init__(self, homepage):
        self.current = homepage
        self.back_stack = StackLL()
        self.forward_queue = QueueLL()

    def visit(self, page):
        print(f"Visiting: {page}")
        self.back_stack.push(self.current)
        self.current = page
        # Clear forward queue by recreating it
        self.forward_queue = QueueLL()

    def back(self):
        if self.back_stack.is_empty():
            print("No Back History")
            return
        self.forward_queue.enqueue(self.current)
        self.current = self.back_stack.pop()
        print(f"Back to: {self.current}")

    def forward(self):
        if self.forward_queue.is_empty():
            print("No Forward History")
            return
        self.back_stack.push(self.current)
        self.current = self.forward_queue.dequeue()
        print(f"Forward to: {self.current}")

    def show_status(self):
        print("\nCurrent Page:", self.current)

browser = BrowserNavigation("Home")

browser.visit("A")
browser.visit("B")
browser.visit("C")

browser.back()        # C -> B
browser.back()        # B -> A
browser.forward()     # A -> B

browser.show_status()
# Out:
# Visiting: A
# Visiting: B
# Visiting: C
# Back to: B
# Back to: A
# Forward to: C
#
# Current Page: C
