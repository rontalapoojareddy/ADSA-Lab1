# %% [markdown]
# <a href="https://colab.research.google.com/github/rontalapoojareddy/ADSA-Lab1/blob/main/ADSA_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Date: 31/10/2025

Lab - 3

Name: Rontala Pooja Reddy

HTNO: 2503B05130

Mtech 1st year '''





class UndoRedoSystem:
    def __init__(self):
        self.undo_stack = []
        self.redo_stack = []

    def perform_action(self, action):
        self.undo_stack.append(action)
        self.redo_stack.clear()
        print("Action performed:", action)

    def undo(self):
        if not self.undo_stack:
            print("Nothing to undo.")
            return
        action = self.undo_stack.pop()
        self.redo_stack.append(action)
        print("Undo:", action)

    def redo(self):
        """Redo the last undone action."""
        if not self.redo_stack:
            print("Nothing to redo.")
            return
        action = self.redo_stack.pop()
        self.undo_stack.append(action)
        print("Redo:", action)

    def display(self):
        """Display current stacks."""
        print("Undo Stack:", self.undo_stack)
        print("Redo Stack:", self.redo_stack)
        print()


# --- Example Usage ---
system = UndoRedoSystem()

system.perform_action("Advanced")
system.perform_action("Data")
system.perform_action("Structures")
system.display()

system.undo()
system.undo()
system.display()

system.redo()
system.display()
# Out:
# Action performed: Advanced
# Action performed: Data
# Action performed: Structures
# Undo Stack: ['Advanced', 'Data', 'Structures']
# Redo Stack: []
#
# Undo: Structures
# Undo: Data
# Undo Stack: ['Advanced']
# Redo Stack: ['Structures', 'Data']
#
# Redo: Data
# Undo Stack: ['Advanced', 'Data']
# Redo Stack: ['Structures']
